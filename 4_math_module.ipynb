# %% [markdown]
# <a href="https://colab.research.google.com/github/Madhu18032000/class4-datatypes/blob/main/4_math_module.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
##1. Write a program to calculate the square root of a number using the `math` module.
import math

num = float(input("Enter a number: "))
print("Square Root =", math.sqrt(num))
# Out:
# Enter a number: 4
# Square Root = 2.0

# %%
#2. Find the cube root of a given number using mathematical operations.
num = float(input("Enter a number: "))
cube_root = num ** (1/3)
print("Cube Root =", cube_root)
# Out:
# Enter a number: 4
# Cube Root = 1.5874010519681994

# %%
##3. Calculate the factorial of a number using `math.factorial()`.

num = int(input("Enter a number: "))
print("Factorial =", math.factorial(num))
# Out:
# Enter a number: 5
# Factorial = 120

# %%
##4.Find the GCD (Greatest Common Divisor) of two numbers using math.gcd()
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

print("GCD =", math.gcd(a, b))
# Out:
# Enter first number: 5
# Enter second number: 6
# GCD = 1

# %%
##5.Find the LCM of two numbers usa = int(input("Enter first number: "))

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

print("LCM =", math.lcm(a, b))
# Out:
# Enter first number: 6
# Enter second number: 8
# LCM = 24

# %%
##6.Calculate the value of 5 raised to the power of 8 using math.pow().
result = math.pow(5, 8)

print(result)
# Out:
# 390625.0

# %%
##7.Find the absolute value of a negative decimal number using math.fabs().
num = -25.75

print(math.fabs(num))
# Out:
# 25.75

# %%
##8.Round a floating-point number up using math.ceil()
num = 8.3

print(math.ceil(num))
# Out:
# 9

# %%
##9.Round a floating-point number to the nearest integer using round().
num = 8.9

print(math.floor(num))
# Out:
# 8

# %%
##10.Round a floating-point number to the nearest integer using round()
num = 8.6

print(round(num))
# Out:
# 9

# %%
##11.Find the remainder of two numbers using math.fmod().
a = 17
b = 5

print(math.fmod(a, b))
# Out:
# 2.0

# %%
##12.Find the quotient and remainder using divmod().
a = 17
b = 5

quotient, remainder = divmod(a, b)

print("Quotient =", quotient)
print("Remainder =", remainder)
# Out:
# Quotient = 3
# Remainder = 2

# %%
##13.Calculate the sine, cosine, and tangent of 45 degrees.
angle = math.radians(45)

print("Sin =", math.sin(angle))
print("Cos =", math.cos(angle))
print("Tan =", math.tan(angle))
# Out:
# Sin = 0.7071067811865475
# Cos = 0.7071067811865476
# Tan = 0.9999999999999999

# %%
##14.Convert an angle from degrees to radians
degree = 90

print(math.radians(degree))
# Out:
# 1.5707963267948966

# %%
##15.Convert an angle from radians to degrees
radian = math.pi

print(math.degrees(radian))
# Out:
# 180.0

# %%
##16.Find the logarithm (base 10) of a number using math.log10().
num = 100

print(math.log10(num))
# Out:
# 2.0

# %%
##17.Find the natural logarithm of a number using math.log().
num = 10

print(math.log(num))
# Out:
# 2.302585092994046

# %%
##18.Calculate e raised to the power of x using math.exp().
x = 5

print(math.exp(x))
# Out:
# 148.4131591025766

# %%
##19.Find the value of π (pi) and Euler's number (e) from the math module.
print("Pi =", math.pi)
print("Euler =", math.e)
# Out:
# Pi = 3.141592653589793
# Euler = 2.718281828459045

# %%
##20.Find the distance between two points using math.dist().
p1 = (2, 3)
p2 = (8, 7)

print(math.dist(p1, p2))
# Out:
# 7.211102550927978

# %%
##21.Calculate the hypotenuse of a right triangle using math.hypot().
a = 3
b = 4

print(math.hypot(a, b))
# Out:
# 5.0

# %%
##22.Find the combination (nCr) using math.comb().
n = 5
r = 2

print(math.comb(n, r))
# Out:
# 10

# %%
##23.Find the permutation (nPr) using math.perm().
n = 5
r = 2

print(math.perm(n, r))
# Out:
# 20

# %%
##24.Check whether a number is finite, infinite, or NaN using math.isfinite(), math.isinf(), and math.isnan().

num = float(input("Enter a number: "))

print("Is Finite :", math.isfinite(num))
print("Is Infinite :", math.isinf(num))
print("Is NaN :", math.isnan(num))
# Out:
# Enter a number: 4
# Is Finite : True
# Is Infinite : False
# Is NaN : False

# %%
##25.Find the product of all numbers in a list using math.prod().

numbers = [2, 3, 4, 5]

print("Product =", math.prod(numbers))
# Out:
# Product = 120

# %%
##26.Find the sum of square roots of all numbers in a list.
numbers = [4, 9, 16, 25]

total = sum(math.sqrt(num) for num in numbers)

print("Sum of Square Roots =", total)
# Out:
# Sum of Square Roots = 14.0

# %%
##27.Find the largest integer less than or equal to the square root of a given number.
num = int(input("Enter a number: "))

result = math.floor(math.sqrt(num))

print("Largest Integer =", result)
# Out:
# Enter a number: 5
# Largest Integer = 2

# %%
##28.Calculate compound interest using math.pow().
principal = float(input("Enter Principal Amount: "))
rate = float(input("Enter Annual Interest Rate (%): "))
time = float(input("Enter Time (Years): "))

amount = principal * math.pow((1 + rate / 100), time)
compound_interest = amount - principal

print("Amount =", amount)
print("Compound Interest =", compound_interest)
# Out:
# Enter Principal Amount: 100000
# Enter Annual Interest Rate (%): 24
# Enter Time (Years): 1
# Amount = 124000.0
# Compound Interest = 24000.0

# %%
###29.Find the area and circumference of a circle using math.pi.
radius = float(input("Enter the radius: "))

area = math.pi * radius ** 2
circumference = 2 * math.pi * radius

print("Area =", area)
print("Circumference =", circumference)
# Out:
# Enter the radius: 5
# Area = 78.53981633974483
# Circumference = 31.41592653589793

# %%
##30.Create a scientific calculator that supports square root, factorial, logarithm, power, trigonometric functions, GCD, and LCM.
import math

print("===== Scientific Calculator =====")
print("1. Square Root")
print("2. Factorial")
print("3. Logarithm (Base 10)")
print("4. Power")
print("5. Trigonometric Functions")
print("6. GCD")
print("7. LCM")

choice = int(input("Enter your choice (1-7): "))

if choice == 1:
    num = float(input("Enter a number: "))
    print("Square Root =", math.sqrt(num))

elif choice == 2:
    num = int(input("Enter a number: "))
    print("Factorial =", math.factorial(num))

elif choice == 3:
    num = float(input("Enter a number: "))
    print("Log10 =", math.log10(num))

elif choice == 4:
    base = float(input("Enter base: "))
    exponent = float(input("Enter exponent: "))
    print("Power =", math.pow(base, exponent))

elif choice == 5:
    angle = float(input("Enter angle in degrees: "))
    rad = math.radians(angle)
    print("Sin =", math.sin(rad))
    print("Cos =", math.cos(rad))
    print("Tan =", math.tan(rad))

elif choice == 6:
    a = int(input("Enter first number: "))
    b = int(input("Enter second number: "))
    print("GCD =", math.gcd(a, b))

elif choice == 7:
    a = int(input("Enter first number: "))
    b = int(input("Enter second number: "))
    print("LCM =", math.lcm(a, b))

else:
    print("Invalid Choice")
# Out:
# ===== Scientific Calculator =====
# 1. Square Root
# 2. Factorial
# 3. Logarithm (Base 10)
# 4. Power
# 5. Trigonometric Functions
# 6. GCD
# 7. LCM
# Enter your choice (1-7): 5
# Enter angle in degrees: 6
# Sin = 0.10452846326765347
# Cos = 0.9945218953682733
# Tan = 0.10510423526567647

# %% [markdown]
# ###python operator

# %% [markdown]
# Arithmatic operator

# %%
##1.Write a program to perform addition, subtraction, multiplication, division, floor division, modulus, and exponentiation on two numbers.
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

print("Addition =", a + b)
print("Subtraction =", a - b)
print("Multiplication =", a * b)
print("Division =", a / b)
print("Floor Division =", a // b)
print("Modulus =", a % b)
print("Exponentiation =", a ** b)
# Out:
# Enter first number: 3
# Enter second number: 4
# Addition = 7
# Subtraction = -1
# Multiplication = 12
# Division = 0.75
# Floor Division = 0
# Modulus = 3
# Exponentiation = 81

# %%
##2.Swap two numbers without using a third variable.
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

a = a + b
b = a - b
a = a - b

print("After Swapping:")
print("a =", a)
print("b =", b)
# Out:
# Enter first number: 67
# Enter second number: 78
# After Swapping:
# a = 78
# b = 67

# %%
##3.Find whether a number is even or odd using the modulus operator.
num = int(input("Enter a number: "))

if num % 2 == 0:
    print("Even Number")
else:
    print("Odd Number")
# Out:
# Enter a number: 67
# Odd Number

# %%
##4.Reverse a three-digit number using arithmetic operators.
num = int(input("Enter a three-digit number: "))

hundreds = num // 100
tens = (num // 10) % 10
ones = num % 10

reverse = ones * 100 + tens * 10 + hundreds

print("Reversed Number =", reverse)
# Out:
# Enter a three-digit number: 45
# Reversed Number = 540

# %%
#5.Find the last digit and first digit of a given number.
num = int(input("Enter a number: "))

last_digit = num % 10

first_digit = num
while first_digit >= 10:
    first_digit = first_digit // 10

print("First Digit =", first_digit)
print("Last Digit =", last_digit)
# Out:
# Enter a number: 56
# First Digit = 5
# Last Digit = 6

# %% [markdown]
# Assignment operator

# %%
#.6emonstrate all assignment operators (=, +=, -=, *=, /=, //=, %= and **=) on a variable.
a = 10

print("Initial Value =", a)

a += 5
print("After += :", a)

a -= 3
print("After -= :", a)

a *= 2
print("After *= :", a)

a /= 4
print("After /= :", a)

a //= 2
print("After //= :", a)

a %= 3
print("After %= :", a)

a **= 2
print("After **= :", a)
# Out:
# Initial Value = 10
# After += : 15
# After -= : 12
# After *= : 24
# After /= : 6.0
# After //= : 3.0
# After %= : 0.0
# After **= : 0.0

# %%
#7.Update a bank account balance using compound assignment operators.
balance = 10000

deposit = 5000
withdraw = 2000

balance += deposit
print("After Deposit =", balance)

balance -= withdraw
print("After Withdrawal =", balance)
# Out:
# After Deposit = 15000
# After Withdrawal = 13000

# %%
#8.Calculate the total marks using += inside a loop.
total = 0

for i in range(5):
    marks = int(input("Enter Marks: "))
    total += marks

print("Total Marks =", total)
# Out:
# Enter Marks: 3
# Enter Marks: 4
# Enter Marks: 9
# Enter Marks: 8
# Enter Marks: 6
# Total Marks = 30

# %% [markdown]
# comparision operator

# %%
#9.Compare two numbers and print the larger number.
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

if a > b:
    print("Larger Number =", a)
else:
    print("Larger Number =", b)
# Out:
# Enter first number: 45
# Enter second number: 56
# Larger Number = 56

# %%
#10.Compare two numbers and print the larger number.
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a == b == c:
    print("All three numbers are equal.")
else:
    print("The numbers are not equal.")
# Out:
# Enter first number: 34
# Enter second number: 345

# %%
#11.Check whether three numbers are equal.

a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a >= b and a >= c:
    print("Largest Number =", a)
elif b >= a and b >= c:
    print("Largest Number =", b)
else:
    print("Largest Number =", c)

# %%
#12.Find the largest among three numbers using comparison operators.
age = int(input("Enter your age: "))

if age >= 18:
    print("Eligible to Vote")
else:
    print("Not Eligible to Vote")

# %% [markdown]
# logical operator

# %%
#13.Check if a person is eligible for a loan (age > 21 AND salary > 30000).

  age = int(input("Enter your age: "))
salary = int(input("Enter your salary: "))

if age > 21 and salary > 30000:
    print("Eligible for Loan")
else:
    print("Not Eligible for Loan")

# %%
#14.Check if a number lies between 10 and 100 using logical operators.
num = int(input("Enter a number: "))

if num >= 10 and num <= 100:
    print("Number lies between 10 and 100")
else:
    print("Number does not lie between 10 and 100")

# %%
#15.Validate username and password using logical operators.
username = input("Enter Username: ")
password = input("Enter Password: ")

if username == "admin" and password == "1234":
    print("Login Successful")
else:
    print("Invalid Username or Password")

# %%
#16.Determine whether a year is a leap year using logical conditions
year = int(input("Enter a year: "))

if (year % 400 == 0) or (year % 4 == 0 and year % 100 != 0):
    print("Leap Year")
else:
    print("Not a Leap Year")

# %% [markdown]
# Bitwise operator

# %%
#17.Find the bitwise AND, OR, XOR of two numbers.
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

print("Bitwise AND =", a & b)
print("Bitwise OR =", a | b)
print("Bitwise XOR =", a ^ b)

# %%
#18.Perform left shift and right shift operations.
num = int(input("Enter a number: "))

print("Left Shift by 1 =", num << 1)
print("Right Shift by 1 =", num >> 1)

# %%
#19.Check whether a number is even using a bitwise operator.
num = int(input("Enter a number: "))

if (num & 1) == 0:
    print("Even Number")
else:
    print("Odd Number")

# %%
#20.Swap two numbers using the XOR operator.
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

a = a ^ b
b = a ^ b
a = a ^ b

print("After Swapping:")
print("a =", a)
print("b =", b)

# %%
#21.Count how many bits are set to 1 in a number using bitwise operations.
num = int(input("Enter a number: "))

count = 0
while num > 0:
    count += num & 1
    num >>= 1

print("Number of Set Bits =", count)

# %% [markdown]
# Identity operator

# %%
#22.Demonstrate the difference between is and ==.
a = [1, 2, 3]
b = [1, 2, 3]

print(a == b)
print(a is b)

# %%
#23.Check whether two variables refer to the same list object.
list1 = [1, 2, 3]
list2 = list1

print(list1 is list2)

# %%
#24.Show the behavior of is not with integers and lists.
# Integers
a = 10
b = 20

print(a is not b)

# Lists
list1 = [1, 2, 3]
list2 = [1, 2, 3]
list3 = list1

print(list1 is not list2)
print(list1 is not list3)

# %% [markdown]
# membership operator

# %%
#25.Check whether a character exists in a string.
string = input("Enter a string: ")
char = input("Enter a character: ")

if char in string:
    print("Character exists in the string")
else:
    print("Character does not exist in the string")

# %%
#26.Check whether a number exists in a list.
numbers = [1, 2, 3, 4, 5]
num = int(input("Enter a number: "))

if num in numbers:
    print("Number exists in the list")
else:
    print("Number does not exist in the list")

# %%
#27.Count how many vowels in a string belong to a predefined vowel list using in.
vowels = ['a', 'e', 'i', 'o', 'u']
string = input("Enter a string: ")

count = 0
for char in string:
    if char in vowels:
        count += 1

print("Number of Vowels =", count)

# %% [markdown]
# Mixed operator

# %%
#27.Build a simple calculator using arithmetic and comparison operators.
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

print("Addition =", a + b)
print("Subtraction =", a - b)
print("Multiplication =", a * b)
print("Division =", a / b)

if a > b:
    print(a, "is greater than", b)
elif a < b:
    print(b, "is greater than", a)
else:
    print("Both numbers are equal")

# %%
#28.Create a grading system using comparison and logical operators.

marks = int(input("Enter your marks: "))

if marks >= 90 and marks <= 100:
    print("Grade A")
elif marks >= 75 and marks < 90:
    print("Grade B")
elif marks >= 60 and marks < 75:
    print("Grade C")
elif marks >= 35 and marks < 60:
    print("Grade D")
elif marks >= 0 and marks < 35:
    print("Fail")
else:
    print("Invalid Marks")

# %%
#29.Build a menu-driven calculator that uses arithmetic, comparison, logical, assignment, membership, identity, and bitwise operators wherever applicable.
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))

print("\n===== MENU =====")
print("1. Arithmetic")
print("2. Comparison")
print("3. Logical")
print("4. Assignment")
print("5. Membership")
print("6. Identity")
print("7. Bitwise")

choice = int(input("Enter your choice: "))

if choice == 1:
    print("Addition =", a + b)
    print("Subtraction =", a - b)
    print("Multiplication =", a * b)
    print("Division =", a / b)

elif choice == 2:
    print("a > b :", a > b)
    print("a < b :", a < b)
    print("a == b :", a == b)

elif choice == 3:
    print("(a > 0 and b > 0) =", a > 0 and b > 0)
    print("(a > 0 or b > 0) =", a > 0 or b > 0)
    print("not(a > b) =", not(a > b))

elif choice == 4:
    x = a
    x += b
    print("After += :", x)
    x -= b
    print("After -= :", x)

elif choice == 5:
    numbers = [10, 20, 30, 40, 50]
    print(a, "in list :", a in numbers)
    print(b, "not in list :", b not in numbers)

elif choice == 6:
    list1 = [1, 2, 3]
    list2 = [1, 2, 3]
    list3 = list1

    print("list1 is list2 :", list1 is list2)
    print("list1 is list3 :", list1 is list3)

elif choice == 7:
    print("AND =", a & b)
    print("OR =", a | b)
    print("XOR =", a ^ b)
    print("Left Shift =", a << 1)
    print("Right Shift =", a >> 1)

else:
    print("Invalid Choice")
