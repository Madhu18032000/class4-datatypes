# %%
# Q0: Print length of Edukron batch text
text = "Edukron Data Science and Data Engineering Batch 2026"
print(len(text))
# Out:
# 52

# %%
# Q1: Positive slice text[0:7]
text = "Edukron Data Science and Data Engineering Batch 2026"
print(text[0:7])
# Out:
# Edukron

# %%
# Q2: Positive slice text[8:12]
text = "Edukron Data Science and Data Engineering Batch 2026"
print(text[8:12])
# Out:
# Data

# %%
# Q3: Positive slice text[13:20]
text = "Edukron Data Science and Data Engineering Batch 2026"
print(text[13:20])
# Out:
# Science

# %%
# Q4: Positive slice text[21:24]
text = "Edukron Data Science and Data Engineering Batch 2026"
print(text[21:24])
# Out:
# and

# %%
# Q5: Positive slice text[25:42]
text = "Edukron Data Science and Data Engineering Batch 2026"
print(text[25:42])
# Out:
# Data Engineering

# %%
# Q6: Positive slice text[30:42]
text = "Edukron Data Science and Data Engineering Batch 2026"
print(text[30:42])
# Out:
# Engineering

# %%
# Q7: Positive slice text[42:48]
text = "Edukron Data Science and Data Engineering Batch 2026"
print(text[42:48])
# Out:
# Batch

# %%
# Q8: Positive slice text[48:52]
text = "Edukron Data Science and Data Engineering Batch 2026"
print(text[48:52])
# Out:
# 2026

# %%
# Q9: Positive slice text[13:29]
text = "Edukron Data Science and Data Engineering Batch 2026"
print(text[13:29])
# Out:
# Science and Data

# %%
# Q10: Positive slice text[8:48]
text = "Edukron Data Science and Data Engineering Batch 2026"
print(text[8:48])
# Out:
# Data Science and Data Engineering Batch

# %%
# Q11: Negative slice text[-52:-45]
text = "Edukron Data Science and Data Engineering Batch 2026"
print(text[-52:-45])
# Out:
# Edukron

# %%
# Q12: Negative slice text[-44:-40]
text = "Edukron Data Science and Data Engineering Batch 2026"
print(text[-44:-40])
# Out:
# Data

# %%
# Q13: Negative slice text[-39:-32]
text = "Edukron Data Science and Data Engineering Batch 2026"
print(text[-39:-32])
# Out:
# Science

# %%
# Q14: Negative slice text[-31:-28]
text = "Edukron Data Science and Data Engineering Batch 2026"
print(text[-31:-28])
# Out:
# and

# %%
# Q15: Negative slice text[-27:-11]
text = "Edukron Data Science and Data Engineering Batch 2026"
print(text[-27:-11])
# Out:
# Data Engineering

# %%
# Q16: Negative slice text[-22:-11]
text = "Edukron Data Science and Data Engineering Batch 2026"
print(text[-22:-11])
# Out:
# Engineering

# %%
# Q17: Negative slice text[-10:-5]
text = "Edukron Data Science and Data Engineering Batch 2026"
print(text[-10:-5])
# Out:
# Batch

# %%
# Q18: Negative slice text[-4:]
text = "Edukron Data Science and Data Engineering Batch 2026"
print(text[-4:])
# Out:
# 2026

# %%
# Q19: Negative slice text[-39:-23]
text = "Edukron Data Science and Data Engineering Batch 2026"
print(text[-39:-23])
# Out:
# Science and Data

# %%
# Q20: Negative slice text[-44:-5]
text = "Edukron Data Science and Data Engineering Batch 2026"
print(text[-44:-5])
# Out:
# Data Science and Data Engineering Batch
