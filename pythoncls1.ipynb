# %% [markdown]
# <a href="https://colab.research.google.com/github/Madhu18032000/class4-datatypes/blob/main/pythoncls1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=10
b=20.6
name="data"

print(a)
print(b)
print(name)
# Out:
# 10
# 20.6
# data

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
a=10
print(a)
type(a)
# Out:
# 10
# int

# %%
a=20.6
print(a)
type(a)
# Out:
# 20.6
# float

# %%
name="machine learning"
print(name)
type(name)
# Out:
# machine learning
# str

# %%
type(2+3j)
# Out:
# complex

# %%
a=2+3j
a.real
# Out:
# 2.0

# %%
a.imag
# Out:
# 3.0

# %%
a= "dats science"
print(a)
# Out:
# dats science

# %%
a= "data engineering"
print(a)
# Out:
# data engineering

# %%
a[3:7]
# Out:
# 'a en'

# %%
text="Edukron Data Science and Data Engineering Batch 2026"

# %% [markdown]
# **bold text**python string index quetions

# %% [markdown]
# 1.write the indexing expression to print "Edukron"?

# %%
text[0:7]
# Out:
# 'Edukron'

# %% [markdown]
# 2.write the indexing expression to print "Data"?

# %%
text[8:13]
# Out:
# 'Data '

# %% [markdown]
# 3.write the indexing expression to print "science"

# %%
text[13:20]
# Out:
# 'Science'

# %% [markdown]
# 4.write the indexing expression to print "and"

# %%
text[21:24]
# Out:
# 'and'

# %% [markdown]
# 5.write the indexing expression to print"Data Engineering"

# %%
text[25:41]
# Out:
# 'Data Engineering'

# %% [markdown]
# 6.write the indexing expression to print "Engineering"

# %%
text[30:41]
# Out:
# 'Engineering'

# %% [markdown]
# 7.write the indexing expression to print "Batch"?

# %%
text[42:47]
# Out:
# 'Batch'

# %% [markdown]
# 8.write the indexing expression to print "2026"

# %%
text[48:54]
# Out:
# '2026'

# %% [markdown]
# 9.write the indexing expression to print "Science and Data"

# %%
text[13:29]
# Out:
# 'Science and Data'

# %% [markdown]
# 10.write the indexing expression to print "Data Science and Data Engineering Batch"

# %%
text[8:47]
# Out:
# 'Data Science and Data Engineering Batch'
